# %%
from file_aggregation import file_aggregation
from train import train
from obtain_metrics import obtain_metrics

X, y, groups = file_aggregation("/Users/reymendoza/Downloads/mit-bih-arrhythmia-database-1.0.0") # preprocessing
fold_results, history_results = train(X, y, groups)
obtain_metrics(fold_results, history_results) # visualizing metrics
# Out:
# Found 46 valid records.
# Excluded records: ['102', '104']
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Fold 1
# Epoch 01 | Train Loss: 0.4809 | Val Loss: 0.5306 | Acc: 0.7269 | Prec: 0.4822 | Rec: 0.3024 | F1: 0.3717 | AUC: 0.7828
# Epoch 02 | Train Loss: 0.2746 | Val Loss: 0.5864 | Acc: 0.7686 | Prec: 0.5852 | Rec: 0.4597 | F1: 0.5149 | AUC: 0.7050
# Epoch 03 | Train Loss: 0.1994 | Val Loss: 0.5838 | Acc: 0.7826 | Prec: 0.6083 | Rec: 0.5229 | F1: 0.5624 | AUC: 0.7278
# Epoch 04 | Train Loss: 0.1661 | Val Loss: 0.5406 | Acc: 0.7822 | Prec: 0.6138 | Rec: 0.4988 | F1: 0.5504 | AUC: 0.7822
# Epoch 05 | Train Loss: 0.1473 | Val Loss: 0.5577 | Acc: 0.7761 | Prec: 0.5849 | Rec: 0.5575 | F1: 0.5708 | AUC: 0.8062
# Epoch 06 | Train Loss: 0.1389 | Val Loss: 0.5123 | Acc: 0.8169 | Prec: 0.6739 | Rec: 0.6097 | F1: 0.6402 | AUC: 0.7957
# Epoch 07 | Train Loss: 0.1296 | Val Loss: 0.5342 | Acc: 0.8134 | Prec: 0.6711 | Rec: 0.5910 | F1: 0.6285 | AUC: 0.7635
# Epoch 08 | Train Loss: 0.1230 | Val Loss: 0.4791 | Acc: 0.8239 | Prec: 0.6843 | Rec: 0.6327 | F1: 0.6574 | AUC: 0.8188
# Epoch 09 | Train Loss: 0.1177 | Val Loss: 0.4928 | Acc: 0.8215 | Prec: 0.6708 | Rec: 0.6516 | F1: 0.6611 | AUC: 0.8103
# Epoch 10 | Train Loss: 0.1127 | Val Loss: 0.5091 | Acc: 0.8087 | Prec: 0.6351 | Rec: 0.6672 | F1: 0.6507 | AUC: 0.8010
# Epoch 11 | Train Loss: 0.1115 | Val Loss: 0.4355 | Acc: 0.8486 | Prec: 0.7450 | Rec: 0.6587 | F1: 0.6992 | AUC: 0.8194
# Epoch 12 | Train Loss: 0.1050 | Val Loss: 0.4379 | Acc: 0.8332 | Prec: 0.6882 | Rec: 0.6870 | F1: 0.6876 | AUC: 0.8529
# Epoch 13 | Train Loss: 0.1054 | Val Loss: 0.4055 | Acc: 0.8510 | Prec: 0.7563 | Rec: 0.6523 | F1: 0.7005 | AUC: 0.8447
# Epoch 14 | Train Loss: 0.1021 | Val Loss: 0.4557 | Acc: 0.8337 | Prec: 0.7157 | Rec: 0.6263 | F1: 0.6680 | AUC: 0.7940
# Epoch 15 | Train Loss: 0.1001 | Val Loss: 0.3724 | Acc: 0.8662 | Prec: 0.8219 | Rec: 0.6373 | F1: 0.7179 | AUC: 0.8556
