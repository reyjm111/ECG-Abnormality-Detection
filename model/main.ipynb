# %%
from file_aggregation import file_aggregation
from train import train
from obtain_metrics import obtain_metrics

X, y, groups = file_aggregation("/Users/reymendoza/Downloads/mit-bih-arrhythmia-database-1.0.0") # preprocessing
fold_results, history_results, best_model_metadata = train(X, y, groups) # training
obtain_metrics(fold_results, history_results) # visualizing metrics
# Out:
# Found 46 valid records.
# Excluded records: ['102', '104']
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
#     Range : 0 ... 180599 =      0.000 ...  1805.990 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=180600
# ...

# %%
best_model_metadata
# Out:
# {'fold': 1,
#  'best_epoch': 44,
#  'train_loss': 0.06619126201703371,
#  'val_loss': 0.18477753167931263,
#  'accuracy': 0.9289091071269289,
#  'precision': 0.7406076445606011,
#  'recall': 0.9986784140969163,
#  'F1': 0.8504970924779591,
#  'auc': 0.9984204084830217,
#  'cm': array([[8147,  794],
#         [   3, 2267]]),
#  'model_path': 'saved_models/ecg_cnn_v1_best_overall.pt'}
